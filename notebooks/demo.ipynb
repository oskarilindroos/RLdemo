# %%
import gymnasium as gym
import tensorflow as tf
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# ## Check GPU availability

# %%
assert tf.config.list_physical_devices('GPU')
assert tf.test.is_built_with_cuda()

# %% [markdown]
# ## Create the learning environment

# %%
#env = Monitor(gym.make('LunarLander-v2', render_mode='human'))
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Create a virtual display for visualizing the environment

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train the agent using PPO (Proximal Policy Optimization) algorithm

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %% [markdown]
# ## Train the model

# %%
model.learn(total_timesteps=1000000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.8     |
# |    ep_rew_mean     | -184     |
# | time/              |          |
# |    fps             | 3735     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 98.7          |
# |    ep_rew_mean          | -151          |
# | time/                   |               |
# |    fps                  | 2758          |
# |    iterations           | 2             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.009995481   |
# |    clip_fraction        | 0.0498        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0032986403 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.56e+03      |
# |    n_updates            | 4             |
# |    policy_gradient_loss | -0.00641      |
# |    value_loss           | 4.62e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 102           |
# |    ep_rew_mean          | -141          |
# | time/                   |               |
# |    fps                  | 2459          |
# |    iterations           | 3             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.0071870796  |
# |    clip_fraction        | 0.0547        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0018988848 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.71e+03      |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.00621      |
# |    value_loss           | 2.76e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 103           |
# |    ep_rew_mean          | -139          |
# | time/                   |               |
# |    fps                  | 2365          |
# |    iterations           | 4             |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.008166065   |
# |    clip_fraction        | 0.0473        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.0024403334 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 707           |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.00508      |
# |    value_loss           | 1.4e+03       |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 110            |
# |    ep_rew_mean          | -115           |
# | time/                   |                |
# |    fps                  | 2301           |
# |    iterations           | 5              |
# |    time_elapsed         | 35             |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | 0.009725349    |
# |    clip_fraction        | 0.0992         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.33          |
# |    explained_variance   | -0.00015115738 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 326            |
# |    n_updates            | 16             |
# |    policy_gradient_loss | -0.00659       |
# |    value_loss           | 1.01e+03       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 119            |
# |    ep_rew_mean          | -109           |
# | time/                   |                |
# |    fps                  | 2223           |
# |    iterations           | 6              |
# |    time_elapsed         | 44             |
# |    total_timesteps      | 98304          |
# | train/                  |                |
# |    approx_kl            | 0.009995447    |
# |    clip_fraction        | 0.11           |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.29          |
# |    explained_variance   | -0.00020670891 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 404            |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -0.00586       |
# |    value_loss           | 959            |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | -76.3        |
# | time/                   |              |
# |    fps                  | 2104         |
# |    iterations           | 7            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.008593868  |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 8.326769e-05 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 311          |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00819     |
# |    value_loss           | 668          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | -52          |
# | time/                   |              |
# |    fps                  | 2092         |
# |    iterations           | 8            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0052456665 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.0751642    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 158          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 424          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -32.1       |
# | time/                   |             |
# |    fps                  | 2065        |
# |    iterations           | 9           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.006139704 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.19566947  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 357         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -23.7        |
# | time/                   |              |
# |    fps                  | 2054         |
# |    iterations           | 10           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0057341945 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.2649107    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 337          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 141          |
# |    ep_rew_mean          | -4.94        |
# | time/                   |              |
# |    fps                  | 1986         |
# |    iterations           | 11           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0042277826 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.44144493   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 221          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | -3.61       |
# | time/                   |             |
# |    fps                  | 1897        |
# |    iterations           | 12          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008878317 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.6853778   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 203         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | -3.96        |
# | time/                   |              |
# |    fps                  | 1773         |
# |    iterations           | 13           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0056862235 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.77011317   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 198          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 299          |
# |    ep_rew_mean          | 4.46         |
# | time/                   |              |
# |    fps                  | 1687         |
# |    iterations           | 14           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0062185647 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.7987514    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.1         |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 196          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 6.91         |
# | time/                   |              |
# |    fps                  | 1603         |
# |    iterations           | 15           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0065696845 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.87667257   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 125          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 155          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 393         |
# |    ep_rew_mean          | 5.38        |
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 16          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.006440154 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.86993253  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 147         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 449          |
# |    ep_rew_mean          | 14.2         |
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 17           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0053499355 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.8689093    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.8         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 472          |
# |    ep_rew_mean          | 30.7         |
# | time/                   |              |
# |    fps                  | 1457         |
# |    iterations           | 18           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0054222145 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.9251995    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.5         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 79.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 469         |
# |    ep_rew_mean          | 40.4        |
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 19          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.005911232 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.91080225  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.4        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 43.7        |
# | time/                   |             |
# |    fps                  | 1408        |
# |    iterations           | 20          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.009529274 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.9273345   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | 46.4        |
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 21          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.003178649 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.9039765   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 565         |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 22          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.004386216 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.9352963   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.5        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 77.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 610         |
# |    ep_rew_mean          | 61.4        |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 23          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.003872441 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.9501838   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.0013     |
# |    value_loss           | 49.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 688          |
# |    ep_rew_mean          | 69.3         |
# | time/                   |              |
# |    fps                  | 1308         |
# |    iterations           | 24           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0034383982 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.9421672    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.4         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000794    |
# |    value_loss           | 72.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 717          |
# |    ep_rew_mean          | 74           |
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 25           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0039538452 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.95047116   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.3         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 63.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 753         |
# |    ep_rew_mean          | 80.8        |
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 26          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.004561931 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.94900143  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 49          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 797         |
# |    ep_rew_mean          | 88          |
# | time/                   |             |
# |    fps                  | 1243        |
# |    iterations           | 27          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.004553671 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.94843423  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.52        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.000443   |
# |    value_loss           | 57.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 825         |
# |    ep_rew_mean          | 97.6        |
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 28          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.009681137 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.96586263  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.21        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 41.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 850         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 1222        |
# |    iterations           | 29          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004761571 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.95443076  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.000757   |
# |    value_loss           | 53.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 831          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 1214         |
# |    iterations           | 30           |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0068378053 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.98304844   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.54         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00013     |
# |    value_loss           | 21           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 840          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 31           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0037523168 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.97311246   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.15         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000655    |
# |    value_loss           | 34.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | 118          |
# | time/                   |              |
# |    fps                  | 1196         |
# |    iterations           | 32           |
# |    time_elapsed         | 438          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0043362826 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.9688375    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 32.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 864         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 33          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.003348902 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.9861998   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.4         |
# |    n_updates            | 128         |
# |    policy_gradient_loss | 0.000212    |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 894         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 34          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.004819717 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.98622465  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.49        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 35          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.005438339 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.9930537   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 7.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 1156         |
# |    iterations           | 36           |
# |    time_elapsed         | 510          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0052956897 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.9880013    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 14.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 951         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 1149        |
# |    iterations           | 37          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.003499478 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.9855894   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00023    |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 958         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 38          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.008279927 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 0.9957312   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.87        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.000241   |
# |    value_loss           | 5.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 951          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 1140         |
# |    iterations           | 39           |
# |    time_elapsed         | 560          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0057896357 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 0.9920755    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 8.62         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 951         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 1133        |
# |    iterations           | 40          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.008876617 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.99120206  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.513       |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 41          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.006843934 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.9974795   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.567       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000592   |
# |    value_loss           | 3.09        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 1127         |
# |    iterations           | 42           |
# |    time_elapsed         | 610          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0039859624 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.99718714   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 3.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 974          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 43           |
# |    time_elapsed         | 625          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0066582127 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.95588493   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 88.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 970          |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 44           |
# |    time_elapsed         | 640          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0031133946 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.98420584   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.87         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | 0.000283     |
# |    value_loss           | 31.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 1123         |
# |    iterations           | 45           |
# |    time_elapsed         | 656          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0022317956 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.8         |
# |    explained_variance   | 0.9772416    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | 0.000472     |
# |    value_loss           | 40.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 46          |
# |    time_elapsed         | 670         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.005293895 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.94043106  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.2         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 109         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 878          |
# |    ep_rew_mean          | 174          |
# | time/                   |              |
# |    fps                  | 1124         |
# |    iterations           | 47           |
# |    time_elapsed         | 685          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0025022805 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.9424653    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 80.5         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000833    |
# |    value_loss           | 105          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 744          |
# |    ep_rew_mean          | 192          |
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 48           |
# |    time_elapsed         | 698          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0043709064 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.9051041    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 205          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 589          |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 1127         |
# |    iterations           | 49           |
# |    time_elapsed         | 711          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0043773935 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.8061639    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 261          |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 439          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 457         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 50          |
# |    time_elapsed         | 724         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.005660207 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.7706436   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 460         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 345          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 51           |
# |    time_elapsed         | 735          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0076528406 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | 0.7855383    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 223          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 376          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 264         |
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 52          |
# |    time_elapsed         | 745         |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004434945 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.6970471   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.4        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 289         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 270          |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 1149         |
# |    iterations           | 53           |
# |    time_elapsed         | 755          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0056932587 |
# |    clip_fraction        | 0.0741       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.83580637   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.2         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 141          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 54          |
# |    time_elapsed         | 765         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.003354467 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.7400527   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.5        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 263         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 272          |
# |    ep_rew_mean          | 265          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 55           |
# |    time_elapsed         | 776          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0052564805 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.708       |
# |    explained_variance   | 0.86673397   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.47         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | 0.000181     |
# |    value_loss           | 104          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 56          |
# |    time_elapsed         | 786         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.002275734 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.8895236   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00037    |
# |    value_loss           | 178         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | 265          |
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 57           |
# |    time_elapsed         | 796          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0056010904 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.9350284    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.61         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000284    |
# |    value_loss           | 69.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 262          |
# |    ep_rew_mean          | 267          |
# | time/                   |              |
# |    fps                  | 1178         |
# |    iterations           | 58           |
# |    time_elapsed         | 806          |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0029217037 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.9054443    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.8         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.000203    |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 263          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 59           |
# |    time_elapsed         | 816          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0055105174 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.9291248    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 138          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 60           |
# |    time_elapsed         | 826          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0023532282 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | 0.9228254    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.7         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.000904    |
# |    value_loss           | 165          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 264         |
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 61          |
# |    time_elapsed         | 837         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.004433106 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.93455905  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.7        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000949   |
# |    value_loss           | 178         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 1198         |
# |    iterations           | 62           |
# |    time_elapsed         | 847          |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0031136838 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.9507748    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.48         |
# |    n_updates            | 244          |
# |    policy_gradient_loss | 4.11e-06     |
# |    value_loss           | 166          |
# ------------------------------------------

# %% [markdown]
# ## Save the model

# %%
model.save("./models/ppo-LunarLander-v2")

# %% [markdown]
# ## Delete the in memory model and load it from a file

# %%
del model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del model  # delete trained model to demonstrate loading
#       2 model = PPO.load("ppo-LunarLander-v2", env=env)
#
# NameError: name 'model' is not defined

# %%
model = PPO.load("./models/ppo-LunarLander-v2", print_system_info=True)
# Out:
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.11.3-2-default-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Fri Oct 11 06:48:36 UTC 2024 (7881e90)
# - Python: 3.11.0rc1
# - Stable-Baselines3: 2.3.2
# - PyTorch: 2.5.0+cu124
# - GPU Enabled: True
# - Numpy: 2.0.2
# - Cloudpickle: 3.1.0
# - Gymnasium: 0.29.1
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.11.3-2-default-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Fri Oct 11 06:48:36 UTC 2024 (7881e90)
# - Python: 3.11.0rc1
# - Stable-Baselines3: 2.3.2
# - PyTorch: 2.5.0+cu124
# - GPU Enabled: True
# - Numpy: 2.0.2
# - Cloudpickle: 3.1.0
# - Gymnasium: 0.29.1

# %% [markdown]
# ## Evaluate the model using a new training environment

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=277.24 +/- 20.09512655789409

# %% [markdown]
# ## Generate a video of the agent

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

env_id = 'LunarLander-v2'
video_folder = './videos/'
video_length = 1000

env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

obs = env.reset()

env = VecVideoRecorder(env, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix="PPO-agent-{}".format(env_id))

env.reset()
for _ in range(video_length + 1):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
# Save the video
env.close()
# Out:
# Saving video to /tf/demo/videos/PPO-agent-LunarLander-v2-step-0-to-step-1000.mp4
# Moviepy - Building video /tf/demo/videos/PPO-agent-LunarLander-v2-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tf/demo/videos/PPO-agent-LunarLander-v2-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tf/demo/videos/PPO-agent-LunarLander-v2-step-0-to-step-1000.mp4

# %%
# %%HTML
# <video width="500" height="500" controls>
#   <source src="./videos/PPO-agent-LunarLander-v2-step-0-to-step-1000.mp4" type="video/mp4">
# </video>
# Out:
# <video width="500" height="500" controls>
#   <source src="./videos/PPO-agent-LunarLander-v2-step-0-to-step-1000.mp4" type="video/mp4">
# </video>
